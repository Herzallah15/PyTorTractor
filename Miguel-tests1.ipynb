# %%
# %run PyTorTractor.py

# %%
O1 = Nucleon(1/2) * Pion(1)
O1_ontime = OpTimeSlice(1, O1)
O2 = bar(O1)
O2_ontime = OpTimeSlice(0, O2)
Correlator = O1_ontime * O2_ontime
Result = Correlator.Laudtracto()
writeresults(Result, O1_ontime, O2_ontime, path = 'PyTor_Test_3.hdf5')#Wichtig
tcmpr = []
for res in Result:
    a = res.bulavision()
    tcmpr.append(np.array(a))

# %%
Hadron1 = Hadron(File_Info_Path = 'baryon_operators.h5', Hadron_Type = 'baryon_operators', Hadron_Position = (1,0), Flavor = 'delta_uud',
          Momentum = 'mom_ray_000', LGIrrep = 'Hg_1', Displacement = 'SS_0')
Hadron2 = Hadron(File_Info_Path = 'baryon_operators.h5', Hadron_Type = 'baryon_operators', Hadron_Position = (0,0), Flavor = 'delta_uud',
          Momentum = 'mom_ray_000', LGIrrep = 'Hg_1', Displacement = 'SS_0')

test0 = PyCorrTorch(SinkTime = 1, SourceTime = 0, 
                   Hadrons = [Hadron1, Hadron2], Path_Wicktract = 'PyTor_Test_3.hdf5', 
                   Path_Perambulator = 'p_snk1_src0.h5',
                   Path_ModeTriplet = 'mode_triplets_1.hdf5', useGPU = True)

# %%
test2 = test0.TorchTractor()
test2

# %%
combine_all(test2)#Finales Ergebnis
